# %%
# !git clone https://huggingface.co/datasets/shellypeng/cartoon-captioned-datasets
# Out:
# Cloning into 'cartoon-captioned-datasets'...
# remote: Enumerating objects: 54, done.
# remote: Total 54 (delta 0), reused 0 (delta 0), pack-reused 54 (from 1)
# Unpacking objects: 100% (54/54), 7.04 KiB | 15.00 KiB/s, done.
# Filtering content: 100% (2/2), 905.43 MiB | 108.81 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/cartoon-captioned-datasets/.git/hooks/post-checkout': Permission denied

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !pip install "jax[cuda12_pip]==0.4.23" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

# %%
# !git clone https://github.com/huggingface/diffusers

# %%
# !git clone https://huggingface.co/CompVis/stable-diffusion-v1-4
# Out:
# Cloning into 'stable-diffusion-v1-4'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (768/768), done.
# remote: Compressing objects: 100% (622/622), done.
# remote: Total 768 (delta 137), reused 768 (delta 137), pack-reused 0 (from 0)
# Receiving objects: 100% (768/768), 685.83 KiB | 3.43 MiB/s, done.
# Resolving deltas: 100% (137/137), done.
# Filtering content: 100% (18/18), 21.71 GiB | 105.68 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/stable-diffusion-v1-4/.git/hooks/post-checkout': Permission denied

# %%
# %cd diffusers
# Out:
# /content/drive/MyDrive/diffusers

# %%
# !pip install .

# %%
# %cd
# Out:
# /root

# %%
# %cd /content/drive/MyDrive/diffusers/examples/dreambooth/
# Out:
# /content/drive/MyDrive/diffusers/examples/dreambooth

# %%
# !pip install -r requirements.txt

# %%
# !pip install wandb

# %%
# %cd /content/drive/MyDrive/diffusers/examples/text_to_image/
# Out:
# /content/drive/MyDrive/diffusers/examples/text_to_image

# %%
from accelerate.utils import write_basic_config

write_basic_config()
# Out:
# PosixPath('/root/.cache/huggingface/accelerate/default_config.yaml')

# %%
MODEL_NAME="/content/drive/MyDrive/stable-diffusion-v1-4"
dataset_name="/content/drive/MyDrive/cartoon-captioned-datasets"

# !accelerate launch train_text_to_image.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$dataset_name \
  --use_ema \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --mixed_precision="fp16" \
  --max_train_steps=8000 \
  --learning_rate=1e-05 \
  --max_grad_norm=1 \
  --report_to="wandb" \
  --lr_scheduler="constant" --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/fine10000"

# %%
# %cd /content/drive/MyDrive/diffusers/examples/textual_inversion/
# Out:
# /content/drive/MyDrive/diffusers/examples/textual_inversion

# %%
# !pip install -r requirements.txt

# %%
MODEL_NAME="/content/drive/MyDrive/stable-diffusion-v1-4"
DATA_DIR="/content/drive/MyDrive/shanshuidata"

# !accelerate launch textual_inversion.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --train_data_dir=$DATA_DIR \
  --learnable_property="style" \
  --placeholder_token="<sks-style>" \
  --initializer_token="style" \
  --resolution=512 \
  --train_batch_size=4 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=500 \
  --learning_rate=5e-6 \
  --scale_lr \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --validation_prompt="a painting of mountains and rivers in <sks-style>" \
  --report_to="wandb" \
  --output_dir="/content/drive/MyDrive/shanshuifine"

# %%
# %cd /content/drive/MyDrive/diffusers/examples/Dreambooth/

# %%
# !pip install -r requirements.txt

# %%
MODEL_NAME="/content/drive/MyDrive/stable-diffusion-v1-4"
INSTANCE_DIR="/content/drive/MyDrive/shanshuidata"
OUTPUT_DIR="/content/drive/MyDrive/dreamfine"
# !accelerate launch train_dreambooth_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME  \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a sks style painting" \
  --resolution=512 \
  --train_batch_size=4 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --report_to="wandb" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --validation_prompt="a painting of mountains and rivers in sks style" \
  --validation_epochs=50 \
  --seed="0"

# %%
MODEL_NAME="/content/drive/MyDrive/stable-diffusion-v1-4"
INSTANCE_DIR="/content/drive/MyDrive/shanshuidata"
OUTPUT_DIR="/content/drive/MyDrive/dreamfine2"
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME  \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a sks style painting of mountains and rivers" \
  --resolution=512 \
  --train_batch_size=4 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --report_to="wandb" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --validation_prompt="a painting of mountains and rivers in sks style" \
  --seed="0"
